# %% [markdown]
# # **Task 5: Question Answering**

# %%
# !pip install git+https://github.com/explosion/spacy-transformers
# !pip install allennlp==2.1.0 allennlp-models==2.1.0
# !pip install -U transformers==3.0.0
# !python -m nltk.downloader punkt
# !git clone https://github.com/patil-suraj/question_generation.git
# !pip install git+https://github.com/boudinfl/pke.git
# !pip install contractions
# !pip install flashtext

# %%
# %cd question_generation

# %%
# %%bash
# nvidia-smi

# %%
# %%bash
# pip install --upgrade pip
# pip install git+https://github.com/deepset-ai/haystack.git#egg=farm-haystack[colab]

# %%
import contractions
import regex as re


def clean(path):
    f = open(path,"r")
    data = f.read()
    data = data.lower()
    x = data
    # delete references
    x = re.sub("[[0-9]+]", "", data)
    # remove arabic words
    x = re.sub("[ا-ي]+", "", x)

    # remove reduntant puctuations
    characters = ['#', '-', '_', '$', '%', '[', ']',
                  '"', '“', '”', '—', '§', '(', ')', '@', '/', '\\', '\n', "'", '+', '&', '=', '+', '*']

    for i in characters:
        x = x.replace(i, '')

    # remove numbers 
    # x = re.sub('[0-9]+', "", x)

    # remove emails
    x = re.sub('([a-zA-Z0-9._-]+@[a-zA-Z0-9._-]+\.[a-zA-Z0-9_-]+)', "", x)

    # conract words
    expanded_words = []
    for word in x.split():
        # using contractions.fix to expand the shortened words
        expanded_words.append(contractions.fix(word))

        for i in range(0, len(expanded_words)-1):
            if expanded_words[i] == expanded_words[i+1]:
                expanded_words[i] = ''
    x = ' '.join(expanded_words)
    
    # handle punctuations
    n = [' ', ',', '.', '=']
    for i in n:
        reg = str("["+i+"]"+"{2,}")
    x = re.sub(reg, i, x)

    x = x.replace('\u200d', '')
    return x

data = clean("data science.txt")

# %%
import pke
d = {}
extractor = pke.unsupervised.TopicRank()
extractor.load_document(input=data, language='en')
extractor.candidate_selection()
extractor.candidate_weighting()
keyphrases = extractor.get_n_best(n=10)
for i in keyphrases:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases,'\n\n')

extractor2 = pke.unsupervised.KPMiner()
extractor2.load_document(input=data, language='en')
extractor2.candidate_selection()
extractor2.candidate_weighting()
keyphrases2 = extractor2.get_n_best(n=10)
for i in keyphrases2:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases2,'\n\n')

extractor3 = pke.supervised.Kea()
extractor3.load_document(input=data, language='en')
extractor3.candidate_selection()
extractor3.candidate_weighting()
keyphrases3 = extractor3.get_n_best(n=10)
for i in keyphrases3:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases3,'\n\n')


extractor4 = pke.unsupervised.MultipartiteRank()
extractor4.load_document(input=data, language='en')
extractor4.candidate_selection()
extractor4.candidate_weighting()
keyphrases4 = extractor4.get_n_best(n=10)
for i in keyphrases4:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases4,'\n\n')


extractor5 = pke.unsupervised.FirstPhrases()
extractor5.load_document(input=data, language='en')
extractor5.candidate_selection()
extractor5.candidate_weighting()
keyphrases5 = extractor5.get_n_best(n=10)
for i in keyphrases5:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases5,'\n\n')


extractor6 = pke.unsupervised.TfIdf()
extractor6.load_document(input=data, language='en')
extractor6.candidate_selection()
extractor6.candidate_weighting()
keyphrases6 = extractor6.get_n_best(n=10)
for i in keyphrases6:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases6,'\n\n')


extractor7 = pke.unsupervised.YAKE()
extractor7.load_document(input=data, language='en')
extractor7.candidate_selection()
extractor7.candidate_weighting()
keyphrases7 = extractor7.get_n_best(n=10)
for i in keyphrases7:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases7,'\n\n')


extractor8 = pke.unsupervised.TextRank()
extractor8.load_document(input=data, language='en')
extractor8.candidate_selection()
extractor8.candidate_weighting()
keyphrases8 = extractor8.get_n_best(n=10)
for i in keyphrases8:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases8,'\n\n')


extractor9 = pke.unsupervised.SingleRank()
extractor9.load_document(input=data, language='en')
extractor9.candidate_selection()
extractor9.candidate_weighting()
keyphrases9 = extractor9.get_n_best(n=10)
for i in keyphrases9:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases9,'\n\n')


extractor10 = pke.unsupervised.TopicalPageRank()
extractor10.load_document(input=data, language='en')
extractor10.candidate_selection()
extractor10.candidate_weighting()
keyphrases10 = extractor10.get_n_best(n=10)
for i in keyphrases10:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases10,'\n\n')


extractor11 = pke.unsupervised.PositionRank()
extractor11.load_document(input=data, language='en')
extractor11.candidate_selection()
extractor11.candidate_weighting()
keyphrases11 = extractor11.get_n_best(n=10)
for i in keyphrases11:
  if i[0] in d:
    tmp = d[i[0]]
    tmp += 1
    d[i[0]] = tmp
  else:
    d[i[0]]=1
print(keyphrases11,'\n\n')
# Out:
# [('unstructured big data', 0.12120316626468171), ('data science', 0.05895596273292368), ('machine', 0.03130913013240335), ('statistics', 0.017106239993124234), ('structured', 0.013176439135407857), ('data modeling', 0.012745444430919385), ('insights', 0.012383006075512236), ('data processing', 0.012084507555545304), ('human brain function', 0.011237253195791408), ('humans', 0.011101741278936018)]
# WARNING:root:LoadFile._df_counts is hard coded to /usr/local/lib/python3.7/dist-packages/pke/models/df-semeval2010.tsv.gz
# [('data science', 751.6131490024901), ('data scientists', 435.14445468565214), ('machine learning', 296.6894009220356), ('big data', 158.23434715841896), ('science', 104.60850064251878), ('huge amounts', 98.89646697401184), ('scientists', 88.21964994859769), ('data', 80.00198847495716), ('data engineers', 79.11717357920948), ('data mining', 79.11717357920948)]
# ...

# %%
lst = []
for i in d:
  if d[i]>3:
    lst.append(i)
lst
# Out:
# ['unstructured big data',
#  'data science',
#  'machine',
#  'data scientists',
#  'machine learning',
#  'big data',
#  'science',
#  'data',
#  'data science algorithms',
#  'data science fields',
#  'data science tools']

# %%
from nltk.tokenize import sent_tokenize
from flashtext import KeywordProcessor
import nltk
nltk.download('punkt')

def tokenize_sentences(text):
    sentences = [sent_tokenize(text)]
    sentences = [y for x in sentences for y in x]
    # Remove any short sentences less than 20 letters.
    sentences = [sentence.strip() for sentence in sentences if len(sentence) > 20]
    return sentences

def get_sentences_for_keyword(keywords, sentences):
    keyword_processor = KeywordProcessor()
    keyword_sentences = {}
    for word in keywords:
        keyword_sentences[word] = []
        keyword_processor.add_keyword(word)
    for sentence in sentences:
        keywords_found = keyword_processor.extract_keywords(sentence)
        for key in keywords_found:
            keyword_sentences[key].append(sentence)

    for key in keyword_sentences.keys():
        values = keyword_sentences[key]
        values = sorted(values, key=len, reverse=True)
        keyword_sentences[key] = values
    return keyword_sentences

sentences = tokenize_sentences(data)
keyword_sentence_mapping = get_sentences_for_keyword(lst, sentences)
        
for i in keyword_sentence_mapping:
  print(i)
  for j in keyword_sentence_mapping[i]:
    print('\t'+j)
  print('\n\n')
# Out:
# unstructured big data
# 	data science enables businesses to process huge amounts of structured and unstructured big data to detect patterns.
#
#
#
# data science
# 	although traditional data analysis programs approach data in a linear fashion, the deep learning systems hierarchy of function enables a nonlinear approach to problems.big data is typically unstructured, so deep learning is an important subset of data science research.statistical methods also ensure data scientists can thoroughly explore and describe data while fairly summarizing them.
# 	data science challenges require the collection, processing, management, analysis, and visualization of mass quantities of data, and data scientists use tools from various fields, including statistics, to achieve those goals.there is a close connection between data science and big data, and most big data exists in unstructured formats and includes some nonnumeric data.
# ...

# %%
tmp = ''
d2 = dict()
for i in keyword_sentence_mapping:
  lt = []
  for j in keyword_sentence_mapping[i]:
    if tmp != j:
      lt.append(j)
      tmp=j
  d2[i]=lt
keyword_sentence_mapping = d2
for i in keyword_sentence_mapping:
  print(i)
  for j in keyword_sentence_mapping[i]:
    print('\t'+j)
  print('\n\n')
# Out:
# unstructured big data
# 	data science enables businesses to process huge amounts of structured and unstructured big data to detect patterns.
#
#
#
# data science
# 	although traditional data analysis programs approach data in a linear fashion, the deep learning systems hierarchy of function enables a nonlinear approach to problems.big data is typically unstructured, so deep learning is an important subset of data science research.statistical methods also ensure data scientists can thoroughly explore and describe data while fairly summarizing them.
# 	data science challenges require the collection, processing, management, analysis, and visualization of mass quantities of data, and data scientists use tools from various fields, including statistics, to achieve those goals.there is a close connection between data science and big data, and most big data exists in unstructured formats and includes some nonnumeric data.
# ...

# %%
from pipelines import pipeline

# %%
nlp = pipeline("e2e-qg")

# %%
import pandas as pd
out = []
for i in keyword_sentence_mapping:
  for j in keyword_sentence_mapping[i]:
    x = nlp(j)
    tmp = []
    tmp.append(i)
    tmp.append(x[0])
    tmp.append(j)
    out.append(tmp)
df = pd.DataFrame(out, columns=['key word', 'question', 'sentence'])
df
# Out:
#                     key word  \
# 0      unstructured big data
# 1               data science
# 2               data science
# 3               data science
# 4               data science
# ..                       ...
# 138                     data
# 139                     data
# 140  data science algorithms
# 141      data science fields
# 142       data science tools
#
#                                               question  \
# 0    What does data science enable businesses to pr...
# 1    What does the deep learning system hierarchy o...
# 2    What type of data requires the collection, pro...
# 3    What is an applied area that sees use in numer...
# 4           What is the raw material for data science?
# ..                                                 ...
# 138                What does the amount of data exist?
# 139     What does a data analyst see at a later stage?
# 140     What is supervised clustering and naive bayes?
# ...

# %% [markdown]
# **Allen NLP model**

# %%
from allennlp.predictors.predictor import Predictor
import allennlp_models.rc

predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/bidaf-elmo.2021-02-11.tar.gz")
# Out:
# ...
# downloading: 100%|##########| 374434792/374434792 [00:26<00:00, 13943667.41B/s]

# %%
res = []
for i, row in df.iterrows():
  tmp = predictor.predict(
    passage= row['sentence'],
    question=row['question']
  )
  res.append(tmp['best_span_str'])
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# /usr/local/lib/python3.7/dist-packages/allennlp_models/rc/models/utils.py:32: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   span_start_indices = best_spans // passage_length

# %%
allen_nlp = df
allen_nlp['answer'] = res
allen_nlp
# Out:
#                     key word  \
# 0      unstructured big data
# 1               data science
# 2               data science
# 3               data science
# 4               data science
# ..                       ...
# 138                     data
# 139                     data
# 140  data science algorithms
# 141      data science fields
# 142       data science tools
#
#                                               question  \
# 0    What does data science enable businesses to pr...
# 1    What does the deep learning system hierarchy o...
# 2    What type of data requires the collection, pro...
# 3    What is an applied area that sees use in numer...
# 4           What is the raw material for data science?
# ..                                                 ...
# 138                What does the amount of data exist?
# 139     What does a data analyst see at a later stage?
# 140     What is supervised clustering and naive bayes?
# ...

# %%
allen_nlp.to_csv('allen-nlp.csv')

# %% [markdown]
# **deberta model**

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/deberta-v3-large-squad2"

# %%
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)

# %%
res = []
for i, row in df.iterrows():
  QA_input = {
    'question': row['question'],
    'context': row['sentence']
  }
  res.append(nlp(QA_input))

# %%
# Filter Answers
res2 = []
for i in range(0, len(res)):
  h = []
  if res[i]['score']>0.8:
      h.append(df['key word'][i])
      h.append(df['sentence'][i])
      h.append(df['question'][i])
      x = str(res[i]['answer'])
      h.append(x)
      res2.append(h)
deberta = pd.DataFrame(res2, columns=['key word', 'sentence', 'question', 'answer'])
deberta
# Out:
#             key word                                           sentence  \
# 0       data science  it does cope with the study of numerical and c...
# 1       data science  characterized by its velocity, variety, and vo...
# 2       data science  in fact, according to mckinsey, applying data ...
# 3       data science  data scientists frequently employ statistical ...
# 4       data science  the term data science analyst really just mean...
# 5       data science  machine learning is the field of data science ...
# 6       data science  the next stage is maintenance, which includes ...
# 7       data science  far from being limited to statistical data iss...
# 8       data science  these 4as of data science are unique to the fi...
# 9       data science  if not, it needs more or better training.data ...
# 10           machine  and while a machine may build its own insights...
# 11           machine  however, the human brain achieves that learnin...
# ...

# %%
deberta.to_csv('deberta.csv')

# %% [markdown]
# **Roberta model**

# %%
model_name = "deepset/roberta-base-squad2"

nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)

res = []
for i, row in df.iterrows():
  QA_input = {
    'question': row['question'],
    'context': row['sentence']
  }
  res.append(nlp(QA_input))

# %%
# Filter Answers
res2 = []
for i in range(0, len(res)):
  h = []
  if res[i]['score']>0.8:
      h.append(df['key word'][i])
      h.append(df['sentence'][i])
      h.append(df['question'][i])
      x = str(res[i]['answer'])
      h.append(x)
      res2.append(h)
roberta = pd.DataFrame(res2, columns=['key word', 'sentence', 'question', 'answer'])
roberta
# Out:
#             key word                                           sentence  \
# 0       data science  it does cope with the study of numerical and c...
# 1       data science  characterized by its velocity, variety, and vo...
# 2       data science  in fact, according to mckinsey, applying data ...
# 3       data science  data scientists frequently employ statistical ...
# 4       data science  the term data science analyst really just mean...
# 5       data science  machine learning is the field of data science ...
# 6       data science  these are all reallife applications for data s...
# 7       data science  these 4as of data science are unique to the fi...
# 8       data science  if not, it needs more or better training.data ...
# 9            machine  and while a machine may build its own insights...
# 10   data scientists  it does cope with the study of numerical and c...
# 11   data scientists  in fact, according to mckinsey, applying data ...
# ...

# %%
roberta.to_csv('roberta.csv')
